# %%
import pandas as pd
import seaborn as sns

# %%
train = pd.read_csv("data/train.csv", names=["rating", "overview", "reviewText"])

# %%
train.head()
# Out:
#    rating                               overview  \
# 0       3                     more like funchuck
# 1       5                              Inspiring
# 2       5  The best soundtrack ever to anything.
# 3       4                       Chrono Cross OST
# 4       5                    Too good to be true
#
#                                           reviewText
# 0  Gave this to my dad for a gag gift after direc...
# 1  I hope a lot of people hear this cd. We need m...
# 2  I'm reading a lot of reviews saying that this ...
# 3  The music of Yasunori Misuda is without questi...
# 4  Probably the greatest soundtrack in history! U...

# %%
train.tail()
# Out:
#          rating                       overview  \
# 2999995       1                  Don't do it!!
# 2999996       2  Looks nice, low functionality
# 2999997       2     compact, but hard to clean
# 2999998       3                 Hard to clean!
# 2999999       1             what is it saying?
#
#                                                 reviewText
# 2999995  The high chair looks great when it first comes...
# 2999996  I have used this highchair for 2 kids now and ...
# 2999997  We have a small house, and really wanted two o...
# 2999998  I agree with everyone else who says this chair...
# 2999999  not sure what this book is supposed to be. It ...

# %%
ax = sns.countplot(x="rating", data=train)

# %%
train.dtypes
# Out:
# rating         int64
# overview      object
# reviewText    object
# dtype: object

# %%
train[train.isnull().any(axis=1)]
# Out:
#          rating overview                                         reviewText
# 22001         2      NaN  What separates this band from Evanescence (bes...
# 104196        4      NaN  I would highly recommend this book. It tells t...
# 124729        2      NaN  This Japanese band produces noisy, psychotic R...
# 144733        2      NaN  this cd isnt band but i wouldnt buy it because...
# 222764        3      NaN  value for the money. enjoyable, convenient, ea...
# 240312        2      NaN  This show lacks many things when compared to C...
# 284971        3      NaN  Out of the pack of 100 I bought, about 5 would...
# 375387        2      NaN  I love bass, love love love it. But the bass o...
# 462559        2      NaN  I am not sure this is the one I am thinking of...
# 509986        2      NaN  i began reading Cold Mountain for my Honors En...
# 529234        4      NaN  Those that still lament the demise of Mayhem s...
# ...

# %%
(train[train.isnull().any(axis=1)].shape[0] / train.shape[0]) * 100
# Out:
# 0.002533333333333333

# %%
ax = sns.countplot(x="rating", data=train[train.isnull().any(axis=1)])

# %%
train["overview"].str.len().values
# Out:
# array([18.,  9., 37., ..., 26., 14., 18.])

# %%
ax = sns.boxplot(x=train["overview"].str.len().values)

# %%
ax = sns.boxplot(x=train["reviewText"].str.len().values)
